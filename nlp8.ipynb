# %% [markdown]
# # Introduction

# %% [markdown]
# ## Pick one of the datasets between hate and offensive, and justify your choice. Remember that it is for a commercial application (there is a good and a bad answer).
#
# ### We have chosen the **Offensive** dataset as the hate one is under the Creative Commons CC-BY-NC-4.0 license where we can't use it for commercial purpose.

# %% [markdown]
# # Evaluating the dataset

# %% [markdown]
# ## Describe the dataset. Look at the splits, proportion of classes, and see what you can figure out by just looking at the text.
#
# #### The dataset is 14.1k rows, wich is note a lot of data, we will probably need more if we want to perform well on the task, furthermore a big model is likely to overfit.
#
# #### The train test split is about 85/15. Depending of how well we perform we may consider using part of the data of testing in the training, reducing the amount for testing.
#
# #### Regarding the class repartition, obviously there are far more non offensive tweets than offensive one, that is something we'll have to keep in mind during the training (about 10% of offensive tweets).

# %%
# !pip install datasets bertopic transformers tqdm shap > /dev/null 2>&1

# %%
from datasets import load_dataset
from bertopic import BERTopic
from sklearn.feature_extraction.text import CountVectorizer
from umap import UMAP

# %%
dataset = load_dataset("tweet_eval", "offensive")
# Out:
# WARNING:datasets.builder:Found cached dataset tweet_eval (/root/.cache/huggingface/datasets/tweet_eval/offensive/1.1.0/12aee5282b8784f3e95459466db4cdf45c6bf49719c25cdb0743d71ed0410343)
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
train_data = dataset['train']
documents = train_data['text']
umap_model = UMAP(random_state=42)
topic_model = BERTopic(embedding_model="all-MiniLM-L6-v2")
topics, probs = topic_model.fit_transform(documents)

# %%
topic_model.visualize_barchart()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="96d62b1c-0117-41f9-93a9-16fc472216ac" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("96d62b1c-0117-41f9-93a9-16fc472216ac")) {                    Plotly.newPlot(                        "96d62b1c-0117-41f9-93a9-16fc472216ac",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.0073359270731639175,0.0075250863905891845,0.008027606160146666,0.01069349329513776,0.04099213855773593],"y":["of  ","the  ","they  ","user  ","antifa  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.008035761393814183,0.013260901620533078,0.013878191119454744,0.038325304327678084,0.04188074580153337],"y":["about  ","laws  ","guns  ","control  ","gun  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.008722320304468595,0.01000722791107016,0.010558855461080255,0.012399054545449345,0.05005003635774339],"y":["are  ","user  ","liberal  ","they  ","liberals  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.01269079306059291,0.012716992358610162,0.013351399930881774,0.015566327791917405,0.01909774816572105],"y":["wrong  ","are  ","you  ","user  ","right  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.011636245682355908,0.016238435506651484,0.017857007160163876,0.021207689156908682,0.02845200416881779],"y":["team  ","game  ","football  ","he  ","nfl  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.008471489426294183,0.008800947438425473,0.013402819399145213,0.01365903153384522,0.0652541438364736],"y":["will  ","ford  ","judge  ","maga  ","kavanaugh  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.013006768149158916,0.013888841680120077,0.02098198808927425,0.025012373674312957,0.05542275983732545],"y":["sister  ","yes  ","her  ","is  ","she  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.008873604701406058,0.009046230330726737,0.009818730762602697,0.010773048104589547,0.05657351095037103],"y":["of  ","they  ","are  ","conservative  ","conservatives  "],"type":"bar","xaxis":"x8","yaxis":"y8"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"], ...

# %%
topics_per_class = topic_model.topics_per_class(documents, train_data['label'])
topic_model.visualize_topics_per_class(topics_per_class, top_n_topics=5)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="10e9043b-f0c6-45dd-a730-fc5cf719ee75" class="plotly-graph-div" style="height:900px; width:1250px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("10e9043b-f0c6-45dd-a730-fc5cf719ee75")) {                    Plotly.newPlot(                        "10e9043b-f0c6-45dd-a730-fc5cf719ee75",                        [{"hoverinfo":"text","hovertext":["<b>Topic 0</b><br>Words: antifa, user, they, the, of","<b>Topic 0</b><br>Words: antifa, fascist, user, they, the"],"marker":{"color":"#E69F00"},"name":"0_antifa_user_they_the","orientation":"h","visible":true,"x":[793,309],"y":[0,1],"type":"bar"},{"hoverinfo":"text","hovertext":["<b>Topic 1</b><br>Words: gun, control, guns, laws, about","<b>Topic 1</b><br>Words: gun, control, guns, laws, about"],"marker":{"color":"#56B4E9"},"name":"1_gun_control_guns_laws","orientation":"h","visible":"legendonly","x":[665,352],"y":[0,1],"type":"bar"},{"hoverinfo":"text","hovertext":["<b>Topic 2</b><br>Words: liberals, they, user, liberal, the","<b>Topic 2</b><br>Words: liberals, they, liberal, are, the"],"marker":{"color":"#009E73"},"name":"2_liberals_they_liberal_user","orientation":"h","visible":"legendonly","x":[228,159],"y":[0,1],"type":"bar"},{"hoverinfo":"text","hovertext":["<b>Topic 3</b><br>Words: right, user, you, wrong, are","<b>Topic 3</b><br>Words: players, door, possible, right, user"],"marker":{"color":"#F0E442"},"name":"3_right_user_you_are","orientation":"h","visible":"legendonly","x":[259,27],"y":[0,1],"type":"bar"},{"hoverinfo":"text","hovertext":["<b>Topic 4</b><br>Words: nfl, he, football, game, league","<b>Topic 4</b><br>Words: nfl, he, football, game, goodell"],"marker":{"color":"#D55E00"},"name":"4_nfl_he_football_game","orientation":"h","visible":"legendonly","x":[168,69],"y":[0,1],"type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.555555555555 ...

# %% [markdown]
# To visualize the topic repartition you can click on the label, default on the first topic

# %% [markdown]
# ## What do you think about the results? How do you think it could impact a model trained on these data?
#
# #### We can see in the topics that tweets were chosen during a short period of time as one of the maiin topic is about a lawyer that made the news in 2018, but is clearly not one of the main topic in general on tweeter
#
# #### We can clearly see disparity of label within topics, which could lead to learning wrong features for our model, and therefore having great chance of error

# %% [markdown]
# ## **Bonus** By default, BERTopic extracts single keywords. Play with the model to extract bigrams or more. See if you can go deeper in your analysis.

# %%
vectorizer_model = CountVectorizer(ngram_range=(2, 2))
topic_model = BERTopic(embedding_model="all-MiniLM-L6-v2", vectorizer_model=vectorizer_model)
topics, probs = topic_model.fit_transform(documents)

# %%
topic_model.visualize_barchart()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="ff18060b-f6dc-46b6-b21c-efae49223de1" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ff18060b-f6dc-46b6-b21c-efae49223de1")) {                    Plotly.newPlot(                        "ff18060b-f6dc-46b6-b21c-efae49223de1",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.007555491487755026,0.00839172056008639,0.011285458655829209,0.013697036415192687,0.013835955568478636],"y":["antifa and  ","antifa is  ","user antifa  ","antifa user  ","user user  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.007906156242535205,0.009259928153339083,0.010732490134498479,0.012460829142782917,0.04111961329621274],"y":["on gun  ","for gun  ","control laws  ","control user  ","gun control  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.011053016820105422,0.017621583653022434,0.018438751693860764,0.019641052648071557,0.02270420477119419],"y":["user user  ","liberals user  ","the liberals  ","liberals are  ","user liberals  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.014096734936701313,0.014633592114430464,0.015456481882259288,0.021491190643584138,0.022694720040505715],"y":["user you  ","correct user  ","user and  ","right user  ","you are  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.007096755157925629,0.007243865027669898,0.007354799691987407,0.007607650767097707,0.011130123852743708],"y":["maga user  ","kavanaugh user  ","kavanaugh is  ","on kavanaugh  ","judge kavanaugh  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.007563651540150336,0.007731118422678037,0.00945456442518792,0.019529359616850653,0.0223137149771615],"y":["the team  ","if he  ","nfl user  ","the nfl  ","he is  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.008451437261695777,0.008451437261695777,0.009376060079278289,0.010403913768976113,0.013644605146671068],"y":["user brexit  ","social housing  ","the uk  ","the user  ","the conservatives  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.009722288633416665,0.012078240124634744,0.01560525805028622,0.0198149843480897,0.021354374635827938],"y":["for conservatives  ","user conservatives  ","the conservatives  ","conservatives user  ","conservatives are  "],"type":"bar","xaxis":"x8","yaxis":"y8"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"t ...

# %%
vectorizer_model = CountVectorizer(ngram_range=(3, 3))
topic_model = BERTopic(embedding_model="all-MiniLM-L6-v2", vectorizer_model=vectorizer_model)
topics, probs = topic_model.fit_transform(documents)
topic_model.visualize_barchart()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="ec8dd339-d459-49f0-b3da-fb283abbf475" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ec8dd339-d459-49f0-b3da-fb283abbf475")) {                    Plotly.newPlot(                        "ec8dd339-d459-49f0-b3da-fb283abbf475",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.002910938351913101,0.0032985827128367835,0.007620813858162073,0.00886344615896596,0.013351401433733433],"y":["user user the  ","user antifa is  ","user user antifa  ","antifa user user  ","user user user  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.007176777011486477,0.008077801688938584,0.00858672181339617,0.01044450117591551,0.011926753772620752],"y":["on gun control  ","control user user  ","for gun control  ","gun control laws  ","gun control user  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.006041969431474998,0.006609312635435503,0.008465649603862835,0.014613911842929386,0.016524449756655853],"y":["user liberals are  ","the liberals user  ","user user user  ","user user liberals  ","liberals user user  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.013029486781874496,0.013211894023568432,0.014043843926296375,0.01458866699467633,0.016403599976894025],"y":["you are right  ","user you are  ","are right user  ","right user user  ","user user you  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.003789314788025402,0.003789314788025402,0.004313722550843961,0.004407579343345634,0.004588849400652316],"y":["kavanaugh he is  ","for judge kavanaugh  ","maga 2a prolife  ","tcot maga rednationrising  ","maga user user  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.0041682673821428155,0.004626348147351589,0.004888815753783883,0.006405397717649467,0.01433627657272163],"y":["many conservatives are  ","the conservatives are  ","user user conservatives  ","for conservatives user  ","conservatives user user  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.023724743202858504,0.027198620951592277,0.02747571892752308,0.05242237021379055,0.07281508562209413],"y":["yes she is  ","is user user  ","who she is  ","user she is  ","she is user  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.019190858239585287,0.019190858239585287,0.020886026843281443,0.021188119972961123,0.021336150215572437],"y":["user fuck off  ","fuck user fuck  ","user oh shit  ","what the fuck  ","the fuck user  "],"type":"bar","xaxis":"x8","yaxis":"y8"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"# ...

# %% [markdown]
# #### Bigram or trigram doesn't seem to affect the topics too much, which are globaly the same.

# %% [markdown]
# # Evaluate a model

# %% [markdown]
# ## Evaluate their model on the test split of the dataset you picked, using precision, recall, and F1-score.

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification

tokenizer = AutoTokenizer.from_pretrained("cardiffnlp/twitter-roberta-base-offensive")

model = AutoModelForSequenceClassification.from_pretrained("cardiffnlp/twitter-roberta-base-offensive")

# %%
import torch

def tokenize(data):
  encoding = tokenizer(data['text'], truncation=True, padding='max_length', max_length=512)
  encoding['labels'] = data['label']


  return encoding

tokenized_test = dataset['test'].map(tokenize, batched=True)
tokenized_test.set_format(type='torch', columns=['input_ids', 'attention_mask', 'labels'])
# Out:
# Map:   0%|          | 0/860 [00:00<?, ? examples/s]

# %%
from torch.utils.data import DataLoader
import torch
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
model.to(device)
data_loader = DataLoader(tokenized_test, batch_size=16)
# Out:
# cuda

# %%
from tqdm import tqdm
def predict(data_loader):
  predictions = []
  labels = []
  texts = []
  probs = []
  model.eval()

  with torch.no_grad():
      for batch in tqdm(data_loader):
          inputs = {key: val.to(device) for key, val in batch.items()}
          outputs = model(**inputs)

          batch_text = [tokenizer.decode(input_id) for input_id in inputs['input_ids']]

          probs.extend(outputs.logits.tolist())
          predictions.extend(torch.argmax(outputs.logits, dim=-1).tolist())
          labels.extend(inputs['labels'].tolist())
          texts.extend(batch_text)
  return predictions, labels, texts, probs

predictions, labels, texts, probs = predict(data_loader)
# Out:
# 100%|██████████| 54/54 [00:24<00:00,  2.23it/s]

# %%
from sklearn.metrics import f1_score, precision_score, recall_score

f1 = f1_score(labels, predictions, average='weighted')
precision = precision_score(labels, predictions, average='weighted')
recall = recall_score(labels, predictions, average='weighted')

print(f'F1 score: {f1}')
print(f'Precision: {precision}')
print(f'Recall: {recall}')
# Out:
# F1 score: 0.8552261168481793
# Precision: 0.8555572351743067
# Recall: 0.8593023255813953

# %% [markdown]
# ## Evaluate their model on the test split of the dataset you picked, using precision, recall, and F1-score.
#
# F1 score: 0.8552261168481793
# Precision: 0.8555572351743067
# Recall: 0.8593023255813953

# %% [markdown]
# ## Look for prediction failures. Extract the top 5 misclassified tweets (highest score in wrong class) for each class and discuss what could be wrong with the model.

# %%
import pandas as pd
df = pd.DataFrame({'labels': labels, 'predictions': predictions, 'texts': texts, 'probs': probs})
df.head()
# Out:
#    labels  predictions                                              texts  \
# 0       1            1  <s>#ibelieveblaseyford is liar she is fat ugly...
# 1       0            1  <s>@user @user @user I got in a pretty deep de...
# 2       0            0  <s>...if you want more shootings and more deat...
# 3       0            0  <s>Angels now have 6 runs. Five of them have c...
# 4       0            0  <s>#Travel #Movies and Unix #Fortune combined ...
#
#                                          probs
# 0    [-0.8861263394355774, 0.8977356553077698]
# 1    [-0.3487536609172821, 0.2542918026447296]
# 2  [0.18577970564365387, -0.20211200416088104]
# 3     [0.6158384680747986, -0.542585015296936]
# 4    [1.2384463548660278, -1.1371604204177856]

# %%
import numpy as np
df['confident'] = df['probs'].apply(np.max)

# %%
df.head()
# Out:
#    labels  predictions                                              texts  \
# 0       1            1  <s>#ibelieveblaseyford is liar she is fat ugly...
# 1       0            1  <s>@user @user @user I got in a pretty deep de...
# 2       0            0  <s>...if you want more shootings and more deat...
# 3       0            0  <s>Angels now have 6 runs. Five of them have c...
# 4       0            0  <s>#Travel #Movies and Unix #Fortune combined ...
#
#                                          probs  confident
# 0    [-0.8861263394355774, 0.8977356553077698]   0.897736
# 1    [-0.3487536609172821, 0.2542918026447296]   0.254292
# 2  [0.18577970564365387, -0.20211200416088104]   0.185780
# 3     [0.6158384680747986, -0.542585015296936]   0.615838
# 4    [1.2384463548660278, -1.1371604204177856]   1.238446

# %%
wrong = df.loc[df.labels != df.predictions]
wrong.sort_values('confident', ascending=False, inplace=True)
wrong.head()
# Out:
#      labels  predictions                                              texts  \
# 96        1            0  <s>#Liberals / #Democrats THIS is what you sta...
# 177       1            0  <s>#Liberals Are Reaching Peak Desperation To ...
# 228       1            0  <s>#BREXIT deal HAS been reached - and will be...
# 418       1            0  <s>#NoPasaran: Unity demo to oppose the far-ri...
# 455       0            1  <s>@user I guess that’s where swamp ass origin...
#
#                                          probs  confident
# 96   [1.3073264360427856, -1.3396073579788208]   1.307326
# 177  [1.1855162382125854, -1.2535228729248047]   1.185516
# 228   [1.1514830589294434, -1.140032410621643]   1.151483
# 418    [1.090884804725647, -1.237762689590454]   1.090885
# 455  [-1.0679528713226318, 1.0643125772476196]   1.064313

# %% [markdown]
# Looking at those tweets it seems to think that political tweet imply offensive language as the top 4 mention democrats, liberals or brexit and is misslabeled as offensive
# I don't really know why the fifth went wrong

# %%
dataset['train'][8]
# Out:
# {'text': '@user Been a Willie fan since before most of you were born....LOVE that he is holding a rally with Beto.... Exactly WHICH fans are furious?  Could you give some specifics?',
#  'label': 0}

# %%
import json

tweets = pd.read_json('/content/tweets.json')

# %%
tweets.head()
# Out:
#                     id               id_str  \
# 0  1410492618790817793  1410492618790817792
# 1  1410492618769780742  1410492618769780736
# 2  1410492618790686720  1410492618790686720
# 3  1410492618803335174  1410492618803335168
# 4  1410492618778157059  1410492618778157056
#
#                                                 text lang  \
# 0  YOU BETTER SUCK HIS DICK KOZY I SEE YOU WITH K...   en
# 1                      I still canr believe it.😭😭😭😭😭   en
# 2  You should raise the webform....how would they...   en
# 3    im tired too but this is so entertaining i cant   en
# 4                                             Fuckof   en
#
#                  created_at
# 0 2021-07-01 06:57:00+00:00
# 1 2021-07-01 06:57:00+00:00
# 2 2021-07-01 06:57:00+00:00
# 3 2021-07-01 06:57:00+00:00
# 4 2021-07-01 06:57:00+00:00

# %%
from torch.utils.data import Dataset
class TextDataset(Dataset):
    def __init__(self, texts, tokenizer, max_length):
        self.texts = texts
        self.tokenizer = tokenizer
        self.max_length = max_length

    def __getitem__(self, idx):
        text = self.texts[idx]
        inputs = self.tokenizer(text, return_tensors='pt', max_length=self.max_length, padding='max_length', truncation=True)
        return {key: tensor.squeeze(0) for key, tensor in inputs.items()}

    def __len__(self):
        return len(self.texts)

tweet_dataset = TextDataset(tweets['text'], tokenizer, max_length=512)
data_loader = DataLoader(tweet_dataset, batch_size=128)

# %% [markdown]
# ## Extract the top 10 tweets your model is most confident about in the target class (offensive or hateful), the top 10 in the neutral class, and the top 10 your model is most uncertain about. Do you believe the model is doing a great job?

# %%
predictions = []
logits = []
texts = []
vectors = []
model.eval()
with torch.no_grad():
  for batch in tqdm(data_loader):
    inputs = {name: tensor.to(device) for name, tensor in batch.items()}
    outputs = model(**inputs)
    vectors.extend(inputs)
    batch_text = [tokenizer.decode(input_id) for input_id in inputs['input_ids']]
    logits.extend(outputs.logits.tolist())
    predictions.extend(torch.argmax(outputs.logits, dim=-1).tolist())
    texts.extend(batch_text)
# Out:
# 100%|██████████| 79/79 [04:59<00:00,  3.79s/it]

# %%
from scipy.special import softmax

preds = pd.DataFrame({'logits': logits, 'predictions': predictions, 'text': texts})
preds['logits'] = preds['logits'].apply(lambda x: softmax(x))

preds['confident'] = preds['logits'].apply(np.max)
preds.head()
# Out:
#                                       logits  predictions  \
# 0  [0.12622787959255163, 0.8737721204074483]            1
# 1  [0.8371830098225985, 0.16281699017740148]            0
# 2   [0.892156637086433, 0.10784336291356696]            0
# 3   [0.6542708146343675, 0.3457291853656325]            0
# 4   [0.4129459193570216, 0.5870540806429785]            1
#
#                                                 text  confident
# 0  <s>YOU BETTER SUCK HIS DICK KOZY I SEE YOU WIT...   0.873772
# 1  <s>I still canr believe it.😭😭😭😭😭</s><pad><pad>...   0.837183
# 2  <s>You should raise the webform....how would t...   0.892157
# 3  <s>im tired too but this is so entertaining i ...   0.654271
# 4  <s>Fuckof</s><pad><pad><pad><pad><pad><pad><pa...   0.587054

# %%
offensive = preds.loc[preds.predictions == 1].sort_values('confident', ascending=False)
neutral = preds.loc[preds.predictions == 0].sort_values('confident', ascending=False)

# %%
offensive.head(10)
# Out:
#                                           logits  predictions  \
# 2198   [0.05152632407768937, 0.9484736759223106]            1
# 7686  [0.053419717404695366, 0.9465802825953046]            1
# 4042    [0.0562603674109664, 0.9437396325890336]            1
# 9867   [0.05765910999295674, 0.9423408900070432]            1
# 9141  [0.060527939532969345, 0.9394720604670306]            1
# 3849   [0.06331532189734886, 0.9366846781026512]            1
# 8073   [0.06748701715796969, 0.9325129828420303]            1
# 1929   [0.06866775949791086, 0.9313322405020892]            1
# 2206   [0.06945895465545943, 0.9305410453445406]            1
# 7800   [0.07109726076346536, 0.9289027392365345]            1
#
#                                                    text  confident
# 2198  <s>don’t you suck his dick or something? ur fu...   0.948474
# 7686  <s>i genuinely feel sick to my stomach and i c...   0.946580
# 4042  <s>You're a little bitch</s><pad><pad><pad><pa...   0.943740
# 9867  <s>Bitch you raggedy af phony ass hoe</s><pad>...   0.942341
# 9141  <s>You're a fucking racist moron</s><pad><pad>...   0.939472
# 3849  <s>Shut the fuck up you damn monkey</s><pad><p...   0.936685
# 8073  <s>its wild how fucking stupid people are</s><...   0.932513
# 1929  <s>Shut the hell up nobody give a shit about y...   0.931332
# 2206  <s>You're a fucking dumbass that think's he's ...   0.930541
# 7800  <s>This dude is a total crybaby man all he doe...   0.928903

# %%
neutral.head(10)
# Out:
#                                           logits  predictions  \
# 7811  [0.9816755049669286, 0.018324495033071365]            0
# 8599   [0.981545555476798, 0.018454444523201923]            0
# 1109  [0.9814001650400814, 0.018599834959918588]            0
# 1416   [0.9809073694650784, 0.01909263053492146]            0
# 8684  [0.9806414513892149, 0.019358548610785054]            0
# 4249  [0.9802667112942776, 0.019733288705722458]            0
# 6506  [0.9802438230663244, 0.019756176933675443]            0
# 4719    [0.979927707378828, 0.02007229262117192]            0
# 7242   [0.9798141271077287, 0.02018587289227117]            0
# 1345  [0.9793971756491799, 0.020602824350820007]            0
#
#                                                    text  confident
# 7811  <s>Thank you beautiful you are too!!🥰</s><pad>...   0.981676
# 8599  <s>Thank you for this! 💜</s><pad><pad><pad><pa...   0.981546
# 1109  <s>Thank you for your supporttt! 😍❤️✨</s><pad>...   0.981400
# 1416  <s>Oh, that would be great. I will be waiting,...   0.980907
# 8684  <s>Aww thank you, Crystal - that means the wor...   0.980641
# 4249  <s>No problem! Thanks for waiting too 🙆🏻‍♀️❤️<...   0.980267
# 6506  <s>Aweeee happy 1 year!!! Hope to see you stre...   0.980244
# 4719  <s>Awe I am so so glad you are getting this. ❤...   0.979928
# 7242  <s>Thank you!! 😭💕</s><pad><pad><pad><pad><pad>...   0.979814
# 1345  <s>Thanks for your kind words ❤️ our team are ...   0.979397

# %%
preds.sort_values('confident', inplace=True)
preds.head(10)
# Out:
#                                          logits  predictions  \
# 5174  [0.49953910209254304, 0.5004608979074571]            1
# 3490  [0.49948020635737367, 0.5005197936426263]            1
# 7104   [0.5005563212358398, 0.4994436787641601]            0
# 4359   [0.5006753565361726, 0.4993246434638275]            0
# 2689   [0.5008012943560514, 0.4991987056439487]            0
# 6390  [0.5008642526351004, 0.49913574736489963]            0
# 2897  [0.5010844824593254, 0.49891551754067465]            0
# 6689   [0.4989024916595031, 0.5010975083404969]            1
# 2662   [0.5011820813038079, 0.4988179186961921]            0
# 1907   [0.5011821693132993, 0.4988178306867007]            0
#
#                                                    text  confident
# 5174  <s>I'm lucky not literate 🙃</s><pad><pad><pad>...   0.500461
# 3490  <s>THE PAIN IN MY ARM WORTHS SO BAD</s><pad><p...   0.500520
# 7104  <s>its crazy to me that people think fictional...   0.500556
# 4359  <s>ok I’m gonna cry now</s><pad><pad><pad><pad...   0.500675
# 2689  <s>someone pinch me i feel like i’m dreaming</...   0.500801
# 6390  <s>MY PHONES DYING</s><pad><pad><pad><pad><pad...   0.500864
# 2897  <s>Why didn’t anyone tell me one piece is also...   0.501084
# 6689  <s>It’s just become a case of ‘this doctor sai...   0.501098
# 2662  <s>this is a big brain moment</s><pad><pad><pa...   0.501182
# 1907  <s>This is just furry and 100 gecs</s><pad><pa...   0.501182

# %% [markdown]
# ## Use SHAP on the provided tweets, or manually written texts, to see if you can find topics on which the model is biased.

# %%
import shap
import scipy as sp

def f(x):
    tv = torch.tensor([tokenizer.encode(v, padding='max_length', max_length=512, truncation=True) for v in x]).cuda()
    outputs = model(tv)[0].detach().cpu().numpy()
    scores = (np.exp(outputs).T / np.exp(outputs).sum(-1)).T
    val = sp.special.logit(scores[:,1]) # use one vs rest logit units
    return val

explainer = shap.Explainer(f, tokenizer)
shap_values = explainer(["A woman who you fucked multiple times saying yo dick small is a compliment you know u hit that spot"])
shap.plots.text(shap_values)
# Out:
#   0%|          | 0/462 [00:00<?, ?it/s]
# Partition explainer: 2it [00:10, 10.78s/it]
#     <br>
#     <hr style="height: 1px; background-color: #fff; border: none; margin-top: 18px; margin-bottom: 18px; border-top: 1px dashed #ccc;"">
#     <div align="center" style="margin-top: -35px;"><div style="display: inline-block; background: #fff; padding: 5px; color: #999; font-family: monospace">[0]</div>
#     </div>
#                 <svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="53.985942561455595%" y1="33" x2="53.985942561455595%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="53.985942561455595%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-0</text><line x1="37.69945440647441%" y1="33" x2="37.69945440647441%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="37.69945440647441%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-1</text><line x1="21.412966251493216%" y1="33" x2="21.412966251493216%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="21.412966251493216%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-2</text><line x1="70.27243071643679%" y1="33" x2="70.27243071643679%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="70.27243071643679%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">1</text><line x1="86.55891887141797%" y1="33" x2="86.55891887141797%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="86.55891887141797%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">2</text><line x1="26.13714802604437%" y1="33" x2="26.13714802604437%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="26.13714802604437%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">-1.70993</text><text x="26.13714802604437%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-1.70993</text><text x="26.13714802604437%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">base value</text><line x1="73.86285181109075%" y1="33" x2="73.86285181109075%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="73.86285181109075%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" font-weight="bold" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">1.22045</text><text x="73.86285181109075%" y="27" font-size="13px" font-weight="bold" fill="rgb(0,0,0)" dominant-baseline="bottom" text-anchor="middle">1.22045</text><text x="73.86285181109075%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">f<tspan baseline-shift="sub" font-size="8px"></tspan>(inputs)</text><rect x="8.33333331976126%" width="65.52951849132948%" y="40" height="18" style="fill:rgb(255.0, 0.0, 81.08083606031792); stroke-width:0; stroke:rgb(0,0,0)" /><line x1="52.442063054269155%" x2="73.86285181109075%" y1="60" y2="60" id="_fb_poepxzhpceayooevgdem_ind_5" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="63.15245743267995%" y="71" font-size="12px" id="_fs_poepxzhpceayooevgdem_ind_5" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle" text-anchor="middle">1.315</text><svg x="52.442063054269155%" y="40" height="20" width="21.420788756821594%">  <svg x="0" y="0" width="100%" height="100%">    <text x="50%" y="9" font-size="12px" fill="rgb(255,255,255)" dominant-baseline="middle" text-anchor="middle">fucked</text>  </svg></svg><line x1="32.82417243855747%" x2="52.442063054269155%" y1="60" y2="60" id="_fb_poepxzhpceayooevgdem_ind_10" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="42.63311774641331%" y="71" font-size="12px" id="_fs_poepxzhpceayooevgdem_ind_10" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle" text-anchor="middle">1.205</text><svg x="32.82417243855747%" y="40" height="20" width="19.617890615711687%">  <svg x="0" y="0" width="100%" height="100%">    <text x="50% ...

# %% [markdown]
# ## What are the advantages of using a pre-trained transformer vs naive Bayes?
#
# #### A pre-trained transformer as the advantage to need far less data to be put in production, as it as already been trained
#
# #### Furthermore it will give better results on new data as it is supposed to have a better generalization of the language

# %% [markdown]
# ## Train a naive Bayes model on the data, and compare its results with this model.

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB

train_texts = dataset['train']['text']
train_labels = dataset['train']['label']
test_texts = dataset['test']['text']
test_labels = dataset['test']['label']

# %%
# Extract features
vectorizer = CountVectorizer()
train_features = vectorizer.fit_transform(train_texts)
test_features = vectorizer.transform(test_texts)

# Train the Naive Bayes classifier
nb_classifier = MultinomialNB()
nb_classifier.fit(train_features, train_labels)

# Make predictions on the test set
pred_labels = nb_classifier.predict(test_features)

# Evaluate the model
f1 = f1_score(test_labels, pred_labels)
precision = precision_score(test_labels, pred_labels)
recall = recall_score(test_labels, pred_labels)

print(f'F1 score: {f1}')
print(f'Precision: {precision}')
print(f'Recall: {recall}')
# Out:
# F1 score: 0.5890109890109891
# Precision: 0.6232558139534884
# Recall: 0.5583333333333333

# %% [markdown]
# ### The naive bayes is really worse than our model, even if we could improve a bit its performances using pretreatment on the data, we still will be far from our model performances.
