# %% [markdown]
# # Introduction

# %% [markdown]
# ## Pick one of the datasets between hate and offensive, and justify your choice. Remember that it is for a commercial application (there is a good and a bad answer).
#
# ### We have chosen the **Offensive** dataset as the hate one is under the Creative Commons CC-BY-NC-4.0 license where we can't use it for commercial purpose.

# %% [markdown]
# # Evaluating the dataset

# %% [markdown]
# ## Describe the dataset. Look at the splits, proportion of classes, and see what you can figure out by just looking at the text.
#
# #### The dataset is 14.1k rows, wich is note a lot of data, we will probably need more if we want to perform well on the task, furthermore a big model is likely to overfit.
#
# #### The train test split is about 85/15. Depending of how well we perform we may consider using part of the data of testing in the training, reducing the amount for testing.
#
# #### Regarding the class repartition, obviously there are far more non offensive tweets than offensive one, that is something we'll have to keep in mind during the training (about 10% of offensive tweets).

# %%
# !pip install datasets bertopic transformers tqdm shap nltk statsmodels > /dev/null 2>&1

# %%
from datasets import load_dataset
from bertopic import BERTopic
from sklearn.feature_extraction.text import CountVectorizer
from umap import UMAP

# %%
dataset = load_dataset("tweet_eval", "offensive")
# Out:
# WARNING:datasets.builder:Found cached dataset tweet_eval (/root/.cache/huggingface/datasets/tweet_eval/offensive/1.1.0/12aee5282b8784f3e95459466db4cdf45c6bf49719c25cdb0743d71ed0410343)
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
train_data = dataset['train']
documents = train_data['text']
umap_model = UMAP(random_state=42)
topic_model = BERTopic(embedding_model="all-MiniLM-L6-v2")
topics, probs = topic_model.fit_transform(documents)

# %%
topic_model.visualize_barchart()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="2059cad4-bbe1-4d8d-9997-eea90d68315e" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2059cad4-bbe1-4d8d-9997-eea90d68315e")) {                    Plotly.newPlot(                        "2059cad4-bbe1-4d8d-9997-eea90d68315e",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.007593590648642721,0.01277895855408384,0.013396180085117483,0.03611500830196068,0.03936304760784744],"y":["about  ","laws  ","guns  ","control  ","gun  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.008727627186582045,0.009396743575813852,0.011471739753913983,0.013260205781784246,0.048627222396510204],"y":["all  ","their  ","liberal  ","they  ","liberals  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.012612803676820775,0.012893809462908076,0.013943152001801552,0.016030284387336405,0.01788723364305618],"y":["you  ","correct  ","user  ","wrong  ","right  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.00744866609405674,0.008203708059697199,0.00877518345528438,0.009387494166999355,0.07483413547341443],"y":["to  ","like  ","user  ","they  ","antifa  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.011560134733589614,0.014635086393563984,0.017343688295237313,0.02522717844825472,0.057023108459399015],"y":["wife  ","yes  ","her  ","is  ","she  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.008206303460678847,0.00839122089362382,0.009773209884630053,0.012456772292419744,0.05147277481783367],"y":["of  ","are  ","they  ","conservative  ","conservatives  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.008495167100838672,0.00905565437962233,0.012276829223658399,0.012487209398124506,0.06806136342139135],"y":["accuser  ","liberals  ","judge  ","maga  ","kavanaugh  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.004366831469976833,0.004879168166211446,0.005834270962636058,0.006455315103930433,0.048180638008725955],"y":["lt  ","gt  ","follow  ","treph  ","user  "],"type":"bar","xaxis":"x8","yaxis":"y8"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"# ...

# %%
topics_per_class = topic_model.topics_per_class(documents, train_data['label'])
topic_model.visualize_topics_per_class(topics_per_class, top_n_topics=5)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="2e3ef859-ab36-4ec4-a925-6fdcc1248c4d" class="plotly-graph-div" style="height:900px; width:1250px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2e3ef859-ab36-4ec4-a925-6fdcc1248c4d")) {                    Plotly.newPlot(                        "2e3ef859-ab36-4ec4-a925-6fdcc1248c4d",                        [{"hoverinfo":"text","hovertext":["<b>Topic 0</b><br>Words: gun, control, guns, laws, nra","<b>Topic 0</b><br>Words: gun, control, guns, laws, about"],"marker":{"color":"#E69F00"},"name":"0_gun_control_guns_laws","orientation":"h","visible":true,"x":[669,353],"y":[0,1],"type":"bar"},{"hoverinfo":"text","hovertext":["<b>Topic 1</b><br>Words: liberals, they, liberal, their, user","<b>Topic 1</b><br>Words: liberals, they, liberal, their, all"],"marker":{"color":"#56B4E9"},"name":"1_liberals_they_liberal_their","orientation":"h","visible":"legendonly","x":[216,146],"y":[0,1],"type":"bar"},{"hoverinfo":"text","hovertext":["<b>Topic 2</b><br>Words: right, wrong, user, correct, you","<b>Topic 2</b><br>Words: possible, right, shedevil, qual, unintentionally"],"marker":{"color":"#009E73"},"name":"2_right_wrong_user_correct","orientation":"h","visible":"legendonly","x":[275,26],"y":[0,1],"type":"bar"},{"hoverinfo":"text","hovertext":["<b>Topic 3</b><br>Words: antifa, they, user, like, one","<b>Topic 3</b><br>Words: antifa, killed, themselves, bashing, them"],"marker":{"color":"#F0E442"},"name":"3_antifa_they_user_like","orientation":"h","visible":"legendonly","x":[202,38],"y":[0,1],"type":"bar"},{"hoverinfo":"text","hovertext":["<b>Topic 4</b><br>Words: she, is, her, yes, wife","<b>Topic 4</b><br>Words: she, is, her, wife, saved"],"marker":{"color":"#D55E00"},"name":"4_she_is_her_yes","orientation":"h","visible":"legendonly","x":[167,44],"y":[0,1],"type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"], ...

# %% [markdown]
# To visualize the topic repartition you can click on the label, default on the first topic

# %% [markdown]
# ## What do you think about the results? How do you think it could impact a model trained on these data?
#
# #### We can see in the topics that tweets were chosen during a short period of time as one of the maiin topic is about a lawyer that made the news in 2018, but is clearly not one of the main topic in general on tweeter
#
# #### We can clearly see disparity of label within topics, which could lead to learning wrong features for our model, and therefore having great chance of error

# %% [markdown]
# ## **Bonus** By default, BERTopic extracts single keywords. Play with the model to extract bigrams or more. See if you can go deeper in your analysis.

# %%
vectorizer_model = CountVectorizer(ngram_range=(2, 2))
topic_model = BERTopic(embedding_model="all-MiniLM-L6-v2", vectorizer_model=vectorizer_model)
topics, probs = topic_model.fit_transform(documents)

# %%
topic_model.visualize_barchart()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="9576fd54-8174-4873-a067-5df16c24afea" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9576fd54-8174-4873-a067-5df16c24afea")) {                    Plotly.newPlot(                        "9576fd54-8174-4873-a067-5df16c24afea",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.0075254228189835905,0.00820984305217872,0.011133886543511252,0.012904803396974994,0.013349606026307886],"y":["antifa and  ","antifa is  ","user antifa  ","user user  ","antifa user  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.007790923554073681,0.009114319313626447,0.010550467892264279,0.012234681198899283,0.03968109370327832],"y":["on gun  ","for gun  ","control laws  ","control user  ","gun control  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.012616348459133717,0.012863986831709117,0.013120048194716126,0.018318573566398277,0.0197634471890682],"y":["correct user  ","user user  ","user and  ","you are  ","right user  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.01132339284077926,0.01926842052070401,0.021248773519458707,0.02212734163452739,0.026001845666646848],"y":["you liberals  ","liberals are  ","the liberals  ","liberals user  ","user liberals  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.0069094250190740655,0.007048275313548275,0.00740703093406023,0.007873439668437407,0.01082358455701881],"y":["maga user  ","kavanaugh user  ","on kavanaugh  ","kavanaugh is  ","judge kavanaugh  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.008238734726957263,0.008238734726957263,0.00912262942761093,0.010072666970098954,0.013189288662988612],"y":["social housing  ","user brexit  ","the uk  ","the user  ","the conservatives  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.010427949292870171,0.011376653576622691,0.01350930964809125,0.015119525630340956,0.06580688164139135],"y":["trump maga  ","you maga  ","thank you  ","user maga  ","maga user  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.01015362818682885,0.012699585470387445,0.018082027401804576,0.022298857591259557,0.02260212202140766],"y":["for conservatives  ","user conservatives  ","the conservatives  ","conservatives user  ","conservatives are  "],"type":"bar","xaxis":"x8","yaxis":"y8"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0," ...

# %%
vectorizer_model = CountVectorizer(ngram_range=(3, 3))
topic_model = BERTopic(embedding_model="all-MiniLM-L6-v2", vectorizer_model=vectorizer_model)
topics, probs = topic_model.fit_transform(documents)
topic_model.visualize_barchart()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="a6729c91-d5b2-46ae-972e-940a80435591" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a6729c91-d5b2-46ae-972e-940a80435591")) {                    Plotly.newPlot(                        "a6729c91-d5b2-46ae-972e-940a80435591",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.006975165711305792,0.007688633917110353,0.008334798847729285,0.010123103533724757,0.011447712499897338],"y":["on gun control  ","control user user  ","for gun control  ","gun control laws  ","gun control user  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.006529079825008018,0.007032601965531224,0.007056510635116336,0.013654610034755613,0.01713033605515355],"y":["user liberals are  ","user user user  ","the liberals user  ","user user liberals  ","liberals user user  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.010664264269646992,0.010894779711672537,0.011481132460565991,0.011647800718264031,0.012510802733903151],"y":["user you are  ","are right user  ","user he is  ","right user user  ","user user you  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.0047536561597302076,0.006366612689692986,0.006979880379610509,0.014375865022548097,0.020417856387772836],"y":["now user user  ","of antifa user  ","antifa user antifa  ","user user antifa  ","antifa user user  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.00381775882905533,0.0038380175598042793,0.004229076406947184,0.004864583839820999,0.012776651882246717],"y":["this is guy  ","user user this  ","the conservatives are  ","for conservatives user  ","conservatives user user  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.003864045714505833,0.003976345571019919,0.004008259526641172,0.004008259526641172,0.005484872993762096],"y":["should be heard  ","tcot maga rednationrising  ","for judge kavanaugh  ","kavanaugh he is  ","maga user user  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.019519718120669747,0.02121208670992436,0.021474208444121397,0.021674510248199035,0.02305187045104848],"y":["user fuck off  ","user oh shit  ","what the fuck  ","the fuck user  ","user holy shit  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.0059572643492784355,0.007148717219134122,0.007148717219134122,0.007926780097363603,0.009974138176088044],"y":["user brexit user  ","user tories user  ","westminster user tories  ","user user brexit  ","tories user user  "],"type":"bar","xaxis":"x8","yaxis":"y8"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0. ...

# %% [markdown]
# #### Bigram or trigram doesn't seem to affect the topics too much, which are globaly the same.

# %% [markdown]
# # Evaluate a model

# %% [markdown]
# ## Evaluate their model on the test split of the dataset you picked, using precision, recall, and F1-score.

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification

tokenizer = AutoTokenizer.from_pretrained("cardiffnlp/twitter-roberta-base-offensive")

model = AutoModelForSequenceClassification.from_pretrained("cardiffnlp/twitter-roberta-base-offensive")

# %%
import torch

def tokenize(data):
  encoding = tokenizer(data['text'], truncation=True, padding='max_length', max_length=512)
  encoding['labels'] = data['label']


  return encoding

tokenized_test = dataset['test'].map(tokenize, batched=True)
tokenized_test.set_format(type='torch', columns=['input_ids', 'attention_mask', 'labels'])
# Out:
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /root/.cache/huggingface/datasets/tweet_eval/offensive/1.1.0/12aee5282b8784f3e95459466db4cdf45c6bf49719c25cdb0743d71ed0410343/cache-1d61ec33e8f7e9fc.arrow

# %%
from torch.utils.data import DataLoader
import torch
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
model.to(device)
data_loader = DataLoader(tokenized_test, batch_size=16)
# Out:
# cuda

# %%
from tqdm import tqdm
def predict(data_loader):
  predictions = []
  labels = []
  texts = []
  probs = []
  model.eval()

  with torch.no_grad():
      for batch in tqdm(data_loader):
          inputs = {key: val.to(device) for key, val in batch.items()}
          outputs = model(**inputs)

          batch_text = [tokenizer.decode(input_id) for input_id in inputs['input_ids']]

          probs.extend(outputs.logits.tolist())
          predictions.extend(torch.argmax(outputs.logits, dim=-1).tolist())
          labels.extend(inputs['labels'].tolist())
          texts.extend(batch_text)
  return predictions, labels, texts, probs

predictions, labels, texts, probs = predict(data_loader)
# Out:
# 100%|██████████| 54/54 [00:27<00:00,  1.97it/s]

# %%
from sklearn.metrics import f1_score, precision_score, recall_score

f1 = f1_score(labels, predictions, average='weighted')
precision = precision_score(labels, predictions, average='weighted')
recall = recall_score(labels, predictions, average='weighted')

print(f'F1 score: {f1}')
print(f'Precision: {precision}')
print(f'Recall: {recall}')
# Out:
# F1 score: 0.8552261168481793
# Precision: 0.8555572351743067
# Recall: 0.8593023255813953

# %% [markdown]
# ## Evaluate their model on the test split of the dataset you picked, using precision, recall, and F1-score.
#
# F1 score: 0.8552261168481793
# Precision: 0.8555572351743067
# Recall: 0.8593023255813953

# %% [markdown]
# ## Look for prediction failures. Extract the top 5 misclassified tweets (highest score in wrong class) for each class and discuss what could be wrong with the model.

# %%
import pandas as pd
df = pd.DataFrame({'labels': labels, 'predictions': predictions, 'texts': texts, 'probs': probs})
df.head()
# Out:
#    labels  predictions                                              texts  \
# 0       1            1  <s>#ibelieveblaseyford is liar she is fat ugly...
# 1       0            1  <s>@user @user @user I got in a pretty deep de...
# 2       0            0  <s>...if you want more shootings and more deat...
# 3       0            0  <s>Angels now have 6 runs. Five of them have c...
# 4       0            0  <s>#Travel #Movies and Unix #Fortune combined ...
#
#                                          probs
# 0    [-0.8861263394355774, 0.8977356553077698]
# 1    [-0.3487536609172821, 0.2542918026447296]
# 2  [0.18577970564365387, -0.20211200416088104]
# 3     [0.6158384680747986, -0.542585015296936]
# 4    [1.2384463548660278, -1.1371604204177856]

# %%
import numpy as np
df['confident'] = df['probs'].apply(np.max)

# %%
df.head()
# Out:
#    labels  predictions                                              texts  \
# 0       1            1  <s>#ibelieveblaseyford is liar she is fat ugly...
# 1       0            1  <s>@user @user @user I got in a pretty deep de...
# 2       0            0  <s>...if you want more shootings and more deat...
# 3       0            0  <s>Angels now have 6 runs. Five of them have c...
# 4       0            0  <s>#Travel #Movies and Unix #Fortune combined ...
#
#                                          probs  confident
# 0    [-0.8861263394355774, 0.8977356553077698]   0.897736
# 1    [-0.3487536609172821, 0.2542918026447296]   0.254292
# 2  [0.18577970564365387, -0.20211200416088104]   0.185780
# 3     [0.6158384680747986, -0.542585015296936]   0.615838
# 4    [1.2384463548660278, -1.1371604204177856]   1.238446

# %%
wrong = df.loc[df.labels != df.predictions]
wrong.sort_values('confident', ascending=False, inplace=True)
wrong.head()
# Out:
#      labels  predictions                                              texts  \
# 96        1            0  <s>#Liberals / #Democrats THIS is what you sta...
# 177       1            0  <s>#Liberals Are Reaching Peak Desperation To ...
# 228       1            0  <s>#BREXIT deal HAS been reached - and will be...
# 418       1            0  <s>#NoPasaran: Unity demo to oppose the far-ri...
# 455       0            1  <s>@user I guess that’s where swamp ass origin...
#
#                                          probs  confident
# 96   [1.3073264360427856, -1.3396073579788208]   1.307326
# 177  [1.1855162382125854, -1.2535228729248047]   1.185516
# 228   [1.1514830589294434, -1.140032410621643]   1.151483
# 418    [1.090884804725647, -1.237762689590454]   1.090885
# 455  [-1.0679528713226318, 1.0643125772476196]   1.064313

# %% [markdown]
# Looking at those tweets it seems to think that political tweet imply offensive language as the top 4 mention democrats, liberals or brexit and is misslabeled as offensive
# I don't really know why the fifth went wrong

# %%
dataset['train'][8]
# Out:
# {'text': '@user Been a Willie fan since before most of you were born....LOVE that he is holding a rally with Beto.... Exactly WHICH fans are furious?  Could you give some specifics?',
#  'label': 0}

# %%
import json

tweets = pd.read_json('/content/tweets.json')

# %%
tweets.head()
# Out:
#                     id               id_str  \
# 0  1410492618790817793  1410492618790817792
# 1  1410492618769780742  1410492618769780736
# 2  1410492618790686720  1410492618790686720
# 3  1410492618803335174  1410492618803335168
# 4  1410492618778157059  1410492618778157056
#
#                                                 text lang  \
# 0  YOU BETTER SUCK HIS DICK KOZY I SEE YOU WITH K...   en
# 1                      I still canr believe it.😭😭😭😭😭   en
# 2  You should raise the webform....how would they...   en
# 3    im tired too but this is so entertaining i cant   en
# 4                                             Fuckof   en
#
#                  created_at
# 0 2021-07-01 06:57:00+00:00
# 1 2021-07-01 06:57:00+00:00
# 2 2021-07-01 06:57:00+00:00
# 3 2021-07-01 06:57:00+00:00
# 4 2021-07-01 06:57:00+00:00

# %%
from torch.utils.data import Dataset
class TextDataset(Dataset):
    def __init__(self, texts, tokenizer, max_length):
        self.texts = texts
        self.tokenizer = tokenizer
        self.max_length = max_length

    def __getitem__(self, idx):
        text = self.texts[idx]
        inputs = self.tokenizer(text, return_tensors='pt', max_length=self.max_length, padding='max_length', truncation=True)
        return {key: tensor.squeeze(0) for key, tensor in inputs.items()}

    def __len__(self):
        return len(self.texts)

tweet_dataset = TextDataset(tweets['text'], tokenizer, max_length=512)
data_loader = DataLoader(tweet_dataset, batch_size=128)

# %% [markdown]
# ## Extract the top 10 tweets your model is most confident about in the target class (offensive or hateful), the top 10 in the neutral class, and the top 10 your model is most uncertain about. Do you believe the model is doing a great job?

# %%
predictions = []
logits = []
texts = []
vectors = []
model.eval()
with torch.no_grad():
  for batch in tqdm(data_loader):
    inputs = {name: tensor.to(device) for name, tensor in batch.items()}
    outputs = model(**inputs)
    vectors.extend(inputs)
    batch_text = [tokenizer.decode(input_id) for input_id in inputs['input_ids']]
    logits.extend(outputs.logits.tolist())
    predictions.extend(torch.argmax(outputs.logits, dim=-1).tolist())
    texts.extend(batch_text)
# Out:
# 100%|██████████| 79/79 [05:10<00:00,  3.92s/it]

# %%
from scipy.special import softmax

preds = pd.DataFrame({'logits': logits, 'predictions': predictions, 'text': texts})
preds['logits'] = preds['logits'].apply(lambda x: softmax(x))

preds['confident'] = preds['logits'].apply(np.max)
preds.head()
# Out:
#                                       logits  predictions  \
# 0  [0.12622787959255163, 0.8737721204074483]            1
# 1  [0.8371830098225985, 0.16281699017740148]            0
# 2   [0.892156637086433, 0.10784336291356696]            0
# 3   [0.6542708146343675, 0.3457291853656325]            0
# 4   [0.4129459193570216, 0.5870540806429785]            1
#
#                                                 text  confident
# 0  <s>YOU BETTER SUCK HIS DICK KOZY I SEE YOU WIT...   0.873772
# 1  <s>I still canr believe it.😭😭😭😭😭</s><pad><pad>...   0.837183
# 2  <s>You should raise the webform....how would t...   0.892157
# 3  <s>im tired too but this is so entertaining i ...   0.654271
# 4  <s>Fuckof</s><pad><pad><pad><pad><pad><pad><pa...   0.587054

# %%
offensive = preds.loc[preds.predictions == 1].sort_values('confident', ascending=False)
neutral = preds.loc[preds.predictions == 0].sort_values('confident', ascending=False)

# %%
offensive.head(10)
# Out:
#                                           logits  predictions  \
# 2198   [0.05152632407768937, 0.9484736759223106]            1
# 7686  [0.053419717404695366, 0.9465802825953046]            1
# 4042    [0.0562603674109664, 0.9437396325890336]            1
# 9867   [0.05765910999295674, 0.9423408900070432]            1
# 9141  [0.060527939532969345, 0.9394720604670306]            1
# 3849   [0.06331532189734886, 0.9366846781026512]            1
# 8073   [0.06748701715796969, 0.9325129828420303]            1
# 1929   [0.06866775949791086, 0.9313322405020892]            1
# 2206   [0.06945895465545943, 0.9305410453445406]            1
# 7800   [0.07109726076346536, 0.9289027392365345]            1
#
#                                                    text  confident
# 2198  <s>don’t you suck his dick or something? ur fu...   0.948474
# 7686  <s>i genuinely feel sick to my stomach and i c...   0.946580
# 4042  <s>You're a little bitch</s><pad><pad><pad><pa...   0.943740
# 9867  <s>Bitch you raggedy af phony ass hoe</s><pad>...   0.942341
# 9141  <s>You're a fucking racist moron</s><pad><pad>...   0.939472
# 3849  <s>Shut the fuck up you damn monkey</s><pad><p...   0.936685
# 8073  <s>its wild how fucking stupid people are</s><...   0.932513
# 1929  <s>Shut the hell up nobody give a shit about y...   0.931332
# 2206  <s>You're a fucking dumbass that think's he's ...   0.930541
# 7800  <s>This dude is a total crybaby man all he doe...   0.928903

# %%
neutral.head(10)
# Out:
#                                           logits  predictions  \
# 7811  [0.9816755049669286, 0.018324495033071365]            0
# 8599   [0.981545555476798, 0.018454444523201923]            0
# 1109  [0.9814001650400814, 0.018599834959918588]            0
# 1416   [0.9809073694650784, 0.01909263053492146]            0
# 8684  [0.9806414513892149, 0.019358548610785054]            0
# 4249  [0.9802667112942776, 0.019733288705722458]            0
# 6506  [0.9802438230663244, 0.019756176933675443]            0
# 4719    [0.979927707378828, 0.02007229262117192]            0
# 7242   [0.9798141271077287, 0.02018587289227117]            0
# 1345  [0.9793971756491799, 0.020602824350820007]            0
#
#                                                    text  confident
# 7811  <s>Thank you beautiful you are too!!🥰</s><pad>...   0.981676
# 8599  <s>Thank you for this! 💜</s><pad><pad><pad><pa...   0.981546
# 1109  <s>Thank you for your supporttt! 😍❤️✨</s><pad>...   0.981400
# 1416  <s>Oh, that would be great. I will be waiting,...   0.980907
# 8684  <s>Aww thank you, Crystal - that means the wor...   0.980641
# 4249  <s>No problem! Thanks for waiting too 🙆🏻‍♀️❤️<...   0.980267
# 6506  <s>Aweeee happy 1 year!!! Hope to see you stre...   0.980244
# 4719  <s>Awe I am so so glad you are getting this. ❤...   0.979928
# 7242  <s>Thank you!! 😭💕</s><pad><pad><pad><pad><pad>...   0.979814
# 1345  <s>Thanks for your kind words ❤️ our team are ...   0.979397

# %%
preds.sort_values('confident', inplace=True)
preds.head(10)
# Out:
#                                          logits  predictions  \
# 5174  [0.49953910209254304, 0.5004608979074571]            1
# 3490  [0.49948020635737367, 0.5005197936426263]            1
# 7104   [0.5005563212358398, 0.4994436787641601]            0
# 4359   [0.5006753565361726, 0.4993246434638275]            0
# 2689   [0.5008012943560514, 0.4991987056439487]            0
# 6390  [0.5008642526351004, 0.49913574736489963]            0
# 2897  [0.5010844824593254, 0.49891551754067465]            0
# 6689   [0.4989024916595031, 0.5010975083404969]            1
# 2662   [0.5011820813038079, 0.4988179186961921]            0
# 1907   [0.5011821693132993, 0.4988178306867007]            0
#
#                                                    text  confident
# 5174  <s>I'm lucky not literate 🙃</s><pad><pad><pad>...   0.500461
# 3490  <s>THE PAIN IN MY ARM WORTHS SO BAD</s><pad><p...   0.500520
# 7104  <s>its crazy to me that people think fictional...   0.500556
# 4359  <s>ok I’m gonna cry now</s><pad><pad><pad><pad...   0.500675
# 2689  <s>someone pinch me i feel like i’m dreaming</...   0.500801
# 6390  <s>MY PHONES DYING</s><pad><pad><pad><pad><pad...   0.500864
# 2897  <s>Why didn’t anyone tell me one piece is also...   0.501084
# 6689  <s>It’s just become a case of ‘this doctor sai...   0.501098
# 2662  <s>this is a big brain moment</s><pad><pad><pa...   0.501182
# 1907  <s>This is just furry and 100 gecs</s><pad><pa...   0.501182

# %% [markdown]
# #### According to the tweets we have just printed, it seemed the model is doing a pretty find job, I don't see enormous mistake in the tweets printed labels.

# %% [markdown]
# ## Use SHAP on the provided tweets, or manually written texts, to see if you can find topics on which the model is biased.

# %%
import shap
import scipy as sp

def f(x):
    tv = torch.tensor([tokenizer.encode(v, padding='max_length', max_length=512, truncation=True) for v in x]).cuda()
    outputs = model(tv)[0].detach().cpu().numpy()
    return outputs

explainer = shap.Explainer(f, tokenizer)
shap_values = explainer(["A woman who you fucked multiple times saying yo dick small is a compliment you know u hit that spot", "Fuck I am an idiot, I spilled milk on my black t-shirt."])
shap.plots.text(shap_values)
# Out:
#   0%|          | 0/462 [00:00<?, ?it/s]
# Partition explainer:  50%|█████     | 1/2 [00:00<?, ?it/s]
#   0%|          | 0/306 [00:00<?, ?it/s]
# Partition explainer: 3it [00:34, 17.06s/it]
# <br>
# <hr style="height: 1px; background-color: #fff; border: none; margin-top: 18px; margin-bottom: 18px; border-top: 1px dashed #ccc;"">
# <div align="center" style="margin-top: -35px;"><div style="display: inline-block; background: #fff; padding: 5px; color: #999; font-family: monospace">[0]</div>
# </div>
#             <div align='center'>
# <script>
#     document._hover_tszvbcxerfnlghsewgxf = '_tp_tszvbcxerfnlghsewgxf_output_0';
#     document._zoom_tszvbcxerfnlghsewgxf = undefined;
#     function _output_onclick_tszvbcxerfnlghsewgxf(i) {
#         var next_id = undefined;
#
#         if (document._zoom_tszvbcxerfnlghsewgxf !== undefined) {
#             document.getElementById(document._zoom_tszvbcxerfnlghsewgxf+ '_zoom').style.display = 'none';
#
#             if (document._zoom_tszvbcxerfnlghsewgxf === '_tp_tszvbcxerfnlghsewgxf_output_' + i) {
#                 document.getElementById(document._zoom_tszvbcxerfnlghsewgxf).style.display = 'block';
#                 document.getElementById(document._zoom_tszvbcxerfnlghsewgxf+'_name').style.borderBottom = '3px solid #000000';
#             } else {
#                 document.getElementById(document._zoom_tszvbcxerfnlghsewgxf).style.display = 'none';
#                 document.getElementById(document._zoom_tszvbcxerfnlghsewgxf+'_name').style.borderBottom = 'none';
#             }
#         }
#         if (document._zoom_tszvbcxerfnlghsewgxf !== '_tp_tszvbcxerfnlghsewgxf_output_' + i) {
#             next_id = '_tp_tszvbcxerfnlghsewgxf_output_' + i;
#             document.getElementById(next_id).style.display = 'none';
#             document.getElementById(next_id + '_zoom').style.display = 'block';
#             document.getElementById(next_id+'_name').style.borderBottom = '3px solid #000000';
#         }
#         document._zoom_tszvbcxerfnlghsewgxf = next_id;
#     }
#     function _output_onmouseover_tszvbcxerfnlghsewgxf(i, el) {
#         if (document._zoom_tszvbcxerfnlghsewgxf !== undefined) { return; }
#         if (document._hover_tszvbcxerfnlghsewgxf !== undefined) {
#             document.getElementById(document._hover_tszvbcxerfnlghsewgxf + '_name').style.borderBottom = 'none';
#             document.getElementById(document._hover_tszvbcxerfnlghsewgxf).style.display = 'none';
#         }
#         document.getElementById('_tp_tszvbcxerfnlghsewgxf_output_' + i).style.display = 'block';
#         el.style.borderBottom = '3px solid #000000';
#         document._hover_tszvbcxerfnlghsewgxf = '_tp_tszvbcxerfnlghsewgxf_output_' + i;
#     }
# </script>
# <div style="color: rgb(120,120,120); font-size: 12px;">outputs</div>
# <div style="display: inline; border-bottom: 3px solid #000000; background: rgba(30.0, 136.0, 229.0, 1.0); border-radius: 3px; padding: 0px" id="_tp_tszvbcxerfnlghsewgxf_output_0_name"
#     onclick="_output_onclick_tszvbcxerfnlghsewgxf(0)"
#     onmouseover="_output_onmouseover_tszvbcxerfnlghsewgxf(0, this);">Output 0</div>
# <div style="display: inline; border-bottom: none; background: rgba(255.0, 13.0, 87.0, 0.7398692810457518); border-radius: 3px; padding: 0px" id="_tp_tszvbcxerfnlghsewgxf_output_1_name"
#     onclick="_output_onclick_tszvbcxerfnlghsewgxf(1)"
#     onmouseover="_output_onmouseover_tszvbcxerfnlghsewgxf(1, this);">Output 1</div><br><br><div id='_tp_tszvbcxerfnlghsewgxf_output_0' style='display: block';><svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="51.34714573551673%" y1="33" x2="51.34714573551673%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="51.34714573551673%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-0</text><line x1="51.34714573551673%" y1="33" x2="51.34714573551673%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="51.34714573551673%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-0</text><line x1="51.34714573551673%" y1="33" x2="51.34714573551673%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="51.34714573551673%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-0</text><line x1="51.34714573551673%" y1="33" x2="51.34714573551673%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="51.34714573551673%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-0</text><line x1="51.34714573551673%" y1="33" x2="51.34714573551673%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="51.34714573551673%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-0</text><line x1="51.34714573551673%" y1="33" x2="51.34714573551673%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="51.34714573551673%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-0</text><line x1="51.34714573551673%" y1="33" x2="51.34714573551673%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="51.34714573551673%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-0</text><line x1="51.34714573551673%" y1="33" x2="51.34714573551673%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="51.34714573551673%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-0</text><line x1="51.34714573551673%" y1="33" x2="51.34714573551673%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="51.34714573551673%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-0</text><line x1="51.34714573551673%" y1="33" x2="51.34714573551673%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="51.34714573551673%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-0</text><line x1="51.34714573551673%" y1="33" x2="51.34714573551673%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="51.34714573551673%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0</text><line x1="51.34714573551673%" y1="33" x2="51.34714573551673%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="51.34714573551673%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0</text><line x1="51.34714573551673%" y1="33" x2="51.34714573551673%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="51.34714573551673%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0</text><line x1="51.34714573551673%" y1="33" x2="51.34714573551673%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="51.34714573551673%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0</text><line x1="51.34714573551673%" y1="33" x2="51.34714573551673%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="51.34714573551673%" y="27" font-size="12px" fill="rgb(1 ...

# %% [markdown]
# Model seems to focus the bad worlds, and does not reflect on multiple world, and thus does't understand irony, it will think that all tweets on minority are offensive tweets.
#
# I tried creating tweets for our model to fail, on the last tweet.

# %% [markdown]
# ## What are the advantages of using a pre-trained transformer vs naive Bayes?
#
# #### A pre-trained transformer as the advantage to need far less data to be put in production, as it as already been trained
#
# #### Furthermore it will give better results on new data as it is supposed to have a better generalization of the language

# %% [markdown]
# ## Train a naive Bayes model on the data, and compare its results with this model.

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB

# %%
def naiveBayes(train_texts, train_labels, test_texts, test_labels):
  # Extract features
  vectorizer = CountVectorizer()
  train_features = vectorizer.fit_transform(train_texts)
  test_features = vectorizer.transform(test_texts)

  # Train the Naive Bayes classifier
  nb_classifier = MultinomialNB()
  nb_classifier.fit(train_features, train_labels)

  # Make predictions on the test set
  pred_labels = nb_classifier.predict(test_features)

  # Evaluate the model
  f1 = f1_score(test_labels, pred_labels)
  precision = precision_score(test_labels, pred_labels)
  recall = recall_score(test_labels, pred_labels)

  print(f'F1 score: {f1}')
  print(f'Precision: {precision}')
  print(f'Recall: {recall}')
  return nb_classifier

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
import re

stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

def preprocess_text(text):

    # Lowercase the text
    text = text.lower()

    # Remove punctuation and special characters
    text = re.sub(r'\W', ' ', text)

    # Tokenize the text
    tokens = word_tokenize(text)

    # Remove stopwords and perform lemmatization
    tokens = [lemmatizer.lemmatize(token) for token in tokens if token not in stop_words]

    return " ".join(tokens)

X_train = [preprocess_text(example['text']) for example in dataset['train']]
y_train = [example['label'] for example in dataset['train']]

X_test = [preprocess_text(example['text']) for example in dataset['test']]
y_test = [example['label'] for example in dataset['test']]

better_model = naiveBayes(X_train, y_train, X_test, y_test)
# Out:
# F1 score: 0.6012793176972282
# Precision: 0.6157205240174672
# Recall: 0.5875

# %% [markdown]
# ### The naive bayes is really worse than our model, it is not a suitable solution for this problem, we achieve performance just a bit better than random

# %% [markdown]
# # Annotate data

# %%
tokens_to_remove = ["<s>","</s>", "<pad>"]

# %%
preds.drop(['logits', 'confident'], inplace=True, axis=1)

# %%
for token in tokens_to_remove:
    preds.text = preds.text.str.replace(token, "")
preds.head(100).predictions.value_counts()
# Out:
# 0    53
# 1    47
# Name: predictions, dtype: int64

# %% [markdown]
# Our model find almost 50% of the head tweets to be offensive, we will noww annotate thme manually

# %%
to_annotate = preds.head(100).drop('predictions', axis=1)
to_annotate.to_excel('/content/to_annotate.xlsx', index=False)

# %% [markdown]
# ## Evaluate your inter-annotaor agreement using Fleiss Kappa.

# %%
import numpy as np
import pandas as pd

df = pd.read_excel('/content/annotated.xlsx')
# Identify all unique categories
categories = np.unique(df.iloc[:, 1:].values)

# Initialize confusion matrix
confusion_matrix = np.zeros((len(df), len(categories)))

# Fill in the confusion matrix
for i, row in df.iterrows():
    for annotation in row[1:]:
        # Find the index of the category in the categories array
        category_index = np.where(categories == annotation)[0][0]
        # Increment the corresponding cell in the confusion matrix
        confusion_matrix[i, category_index] += 1

# %%
from statsmodels.stats.inter_rater import fleiss_kappa

kappa_score = fleiss_kappa(confusion_matrix)
print(kappa_score)
# Out:
# 0.377557489481874

# %% [markdown]
# The kappa score is really low, showing that the guideline are not preciseenough. Also we found the data without context hard to evaluate, what could justify the absence of consensus on them.
#
# After researching on the web, a score below .40 is bad, beetween .40 and .75 is normal, and above is great

# %% [markdown]
# ## Bonus Evaluate the model your data. Use a majority vote for labels (remove majority "can't tell") and compute the precision, recall, and F1-score.

# %%
from collections import Counter
def majority(row):
    counter = Counter(row)
    max_count = max(list(counter.values()))
    mode_val = [num for num, freq in counter.items() if freq == max_count]
    if len(mode_val) == 1:
        return mode_val[0]
    else:
        return None

df['label'] = df[['Mathieu', 'Noé', 'Armand']].apply(majority, axis=1)
df['label'] = df['label'].astype('Int64')
df.label.value_counts()
# Out:
# 0    78
# 1    19
# 2     1
# Name: label, dtype: Int64

# %% [markdown]
# We have one unsure, well drop it

# %%
df.sort_values('label', ascending=False, inplace=True)
df.head()
df = df.drop(10)
df = df.dropna()

# %%
from datasets import Dataset

tweet_dataset = Dataset.from_pandas(df)
tokenized_tweets = tweet_dataset.map(tokenize, batched=True)
tokenized_tweets.set_format(type='torch', columns=['input_ids', 'attention_mask', 'labels'])
data_loader = DataLoader(tokenized_tweets, batch_size=16)
tweet_dataset
# Out:
# Map:   0%|          | 0/97 [00:00<?, ? examples/s]
# Dataset({
#     features: ['text', 'Mathieu', 'Noé', 'Armand', 'label', '__index_level_0__'],
#     num_rows: 97
# })

# %%
predictions, labels, texts, probs = predict(data_loader)

f1 = f1_score(labels, predictions, average='weighted')
precision = precision_score(labels, predictions, average='weighted')
recall = recall_score(labels, predictions, average='weighted')

print(f'F1 score: {f1}')
print(f'Precision: {precision}')
print(f'Recall: {recall}')
# Out:
# 100%|██████████| 7/7 [00:03<00:00,  2.31it/s]
# F1 score: 0.6116623711340207
# Precision: 0.7282932416953035
# Recall: 0.5670103092783505

# %% [markdown]
# The score on our datas are
# F1 score: 0.6116623711340207
# Precision: 0.7282932416953035
# Recall: 0.5670103092783505
#
# It shows that our model has trouble finding offensive tweets because the recall is low, but fro its defense we had trouble too withg those data, even our group had trouble to labelized those tweets.
#
# This model could be a good first sort of tweets, before an human check manually the tweet.
